# %%
# %pip install -U langchain
# %pip install -qU langchain-community 
# Install package, compatible with API partitioning
# %pip install -qU langchain-community pypdf
# %pip install langchain unstructured[pdf] pdfminer.six
# pip install unstructured
# %pip install unstructured-inference
# %pip install camelot-py[cv] pdfplumber pandas
# pip install sentence-transformers

# %%
import os
import pickle
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

import pdfloader
import webloader

from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceBgeEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_community.vectorstores.faiss import DistanceStrategy
from langchain_classic.chains import RetrievalQA
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %% [markdown]
# # Сбор данных

# %% [markdown]
# Итоговая реализация сохранена в `loader.py`

# %%
# website for parsing
url_isu = 'https://www.isu.org/figure-skating-rules/?tab=ISU%20Judging%20System'
# pdf for parsing
INPUT_PDF_PATH = 'pdf_rules'
PROF_PATH = os.path.join(INPUT_PDF_PATH,'Профессионалы')
LOVER_PATH = os.path.join(INPUT_PDF_PATH,'Любители')
ISU_PATH = os.path.join(INPUT_PDF_PATH,'ISU')

# all pdf files
prof_pdf_rules = os.listdir(PROF_PATH)
lover_pdf_rules = os.listdir(LOVER_PATH)
isu_pdf_rules = os.listdir(ISU_PATH)

prof_pdf_rules = [os.path.join(PROF_PATH, f)  for f in prof_pdf_rules]
lover_pdf_rules = [os.path.join(LOVER_PATH, f)  for f in lover_pdf_rules]
isu_pdf_rules = [os.path.join(ISU_PATH, f)  for f in isu_pdf_rules]

# общее количество правил в pdf
all_pdf = prof_pdf_rules + lover_pdf_rules + isu_pdf_rules; len(all_pdf)
# Out:
# 27

# %% [markdown]
# ## Веб-ресурсы

# %%
docs_web = webloader.load_url(url_isu)
docs_web[0].page_content
# Out:
# "Sports Rules - International Skating Union Homenews Events E-Rink Presshome of skating Governance History About ISUISU Constitution Structure Members Athletes Commission Transparencydown-arrow ISU Congresses Decision of the Council ISU Communications ISU Policies Strategy & Financial Reports Disciplinary Decisions Jobs Tenders & Bids Prevention of Manipulation of Competition Development Development Development Projects Visiting ISU Coach ISU Development Camps Scholarships Annual Contributions Center of excellence World Ice Skating Daye-Rink Olympic Solidarity Sports rules Sports rules Rule Change Proposal ISU Communications Anti-Doping Anti-Doping Rules Guidelines for Skaters PURE AS ICE - Education/Prevention Anti-Doping Program Guidelines for ISU Events Medical & Health ISU Medical Form Guidelines for ISU Events Health Harassment and abuse in sport Safeguarding Sustainability Homenews Events E-Rink Press Governance+Development+Sport Rules+anti-doping+Medical & Health+Safeguarding Sustainabilityhome of skatingsocial Figure Skating Speed Skating Figure Skating Speed Skating Figure Skating Speed Skatinghome of skating News Development SPORTS RULESMedical & Health Sustainability Press Anti-doping Safeguarding ISU Communications Careers Contact Us2025 © All rights reserved. International Skating Unionterms of serviceprivacy policy Sports Rules Figure Skating Rules Figure Skating Rules Synchronized Skating Rules Speed Skating Rules Short Track Rules ISU Constitution 202503 Jul 2025 Special Regulations & Technical Rules27 Nov 2024 ISU Judging System Handbooks Single & Pair Skating Handbooks Ice Dance Forms, Reports & Seminars Technical Panel The Technical Panel is composed of the Technical Controller and two Technical Specialists, each one from different ISU Members (countries). A Data Operator assists them for recording purposes. An instantaneous slow-motion video replay system operated by a Replay Operator supports the Technical Panel in the identification of the performed elements.The Technical Specialists identify and call the performed elements and the specific Levels of Difficulty of certain performed elements (e.g. spins, footwork). They identify illegal or additional elements and falls.The Technical Controller authorizes and/or corrects all calls, supervises the Data Operator and can propose corrections, if necessary.In case of disagreement, the majority among the three Officials prevails.Judges Under the ISU Judging System the Judges focus entirely on evaluating the quality of each element performed (Technical Score) and the quality of the performance (Presentation Score)Their scores will be based on specific quality criteria for each element and will provide a comprehensive assessment of each skater’s skills and performance, without comparing each skater in relation to all others. The Judge enters the scores through a touch screen unit. At ISU Events, Judges may review in real time certain elements of the skaters’ performances by means of an instantaneous Video Replay System.Panel of Judges There will be a panel of a maximum of 9 Judges per segment. The scores of these Judges will form the result. Out of these scores, the highest and lowest score of each element or program component are ignored and the average will be taken from the remainder, generating the trimmed mean (average score). The referee is the official responsible for the event in accordance with official rules and the panel of Judges.Technical Score Every Required Element of the Short Program, Free Skating, Rhythm Dance and Free Dance is assigned a base value. Base values of all recognised elements are published annually by the ISU in the Scale of Value chart.The base value of the elements is depending on the number of rotations for jumps or the assigned level of difficulty for elements such as spins, steps, lifts, twizzles, etc. The values are decided by an expert group which includes experienced skaters and coaches.\xa0During the performance the Technical ...

# %% [markdown]
# ## PDF

# %%
# для проверки сохраняем в .txt, чтобы посмотреть на результат
TXT_CHECK_DIRR = 'extract_pdf'
def save_txt_result(pdf_file, final_docs):
    txt_file = os.path.join(TXT_CHECK_DIRR, os.path.splitext(pdf_file.split('\\')[-1])[0] + ".txt")

    final_docs_sorted = sorted(final_docs, key=lambda d: d.metadata.get("page_number", 0))

    with open(txt_file, "w", encoding="utf-8") as f:
        for i, doc in enumerate(final_docs_sorted):
            if i > 0:
                f.write("\n\n\n")
            f.write(doc.page_content)

# %%
all_docs = []
error_pdf_files = []

for pdf_file in tqdm(all_pdf, desc="Loading PDFs"):
    try:
        # загружаем пдф
        docs_pdf = pdfloader.load_pdf(pdf_file)
        all_docs.extend(docs_pdf)
        # сохраняем промежуточный результат 
        save_txt_result(pdf_file, docs_pdf) 
        
    except Exception as e:
        print(f"error {pdf_file}: {e}")
        error_pdf_files.append(pdf_file)

all_docs.extend(docs_web)
# Out:
# Loading PDFs:   0%|          | 0/27 [00:00<?, ?it/s]
# Processing: pdf_rules\Профессионалы\ПРАВИЛА ВИДА СПОРТА фигурное катание.pdf
# Warning: No languages specified, defaulting to English.
# `mode='paged'` is deprecated in favor of the 'by_page' chunking strategy. Learn more about chunking here: https://docs.unstructured.io/open-source/core-functionality/chunking
# Loading PDFs:   4%|▎         | 1/27 [01:43<44:44, 103.24s/it]
# Processing: pdf_rules\Профессионалы\Разряды.pdf
# Warning: No languages specified, defaulting to English.
# `mode='paged'` is deprecated in favor of the 'by_page' chunking strategy. Learn more about chunking here: https://docs.unstructured.io/open-source/core-functionality/chunking
# Loading PDFs:   7%|▋         | 2/27 [02:16<25:45, 61.83s/it]
# Processing: pdf_rules\Профессионалы\Руководство Технических бригад Одиночное катание.pdf
# Warning: No languages specified, defaulting to English.
# `mode='paged'` is deprecated in favor of the 'by_page' chunking strategy. Learn more about chunking here: https://docs.unstructured.io/open-source/core-functionality/chunking
# Loading PDFs:  11%|█         | 3/27 [02:54<20:27, 51.14s/it]
# Processing: pdf_rules\Профессионалы\Руководство Технических бригад Парное катание.pdf
# `mode='paged'` is deprecated in favor of the 'by_page' chunking strategy. Learn more about chunking here: https://docs.unstructured.io/open-source/core-functionality/chunking
# Warning: No languages specified, defaulting to English.
# Loading PDFs:  15%|█▍        | 4/27 [03:32<17:37, 45.97s/it]
# Processing: pdf_rules\Профессионалы\Руководство технических бригад Синхронное катание.pdf
# Warning: No languages specified, defaulting to English.
# `mode='paged'` is deprecated in favor of the 'by_page' chunking strategy. Learn more about chunking here: https://docs.unstructured.io/open-source/core-functionality/chunking
# Loading PDFs:  19%|█▊        | 5/27 [03:49<12:59, 35.41s/it]
# Processing: pdf_rules\Профессионалы\ТЕХНИЧЕСКИЕ ТРЕБОВАНИЯ ПО ОДИНОЧНОМУ И ПАРНОМУ КАТАНИЮ.pdf
# Warning: No languages specified, defaulting to English.
# `mode='paged'` is deprecated in favor of the 'by_page' chunking strategy. Learn more about chunking here: https://docs.unstructured.io/open-source/core-functionality/chunking
# Loading PDFs:  22%|██▏       | 6/27 [04:53<15:52, 45.35s/it]`mode='paged'` is deprecated in favor of the 'by_page' chunking strategy. Learn more about chunking here: https://docs.unstructured.io/open-source/core-functionality/chunking
# Processing: pdf_rules\Профессионалы\Хореографическая спираль.pdf
# Warning: No languages specified, defaulting to English.
# Loading PDFs:  26%|██▌       | 7/27 [04:54<10:16, 30.84s/it]
# Processing: pdf_rules\Любители\ПРЕДВАРИТЕЛЬНЫЕ_СПЕЦИАЛЬНЫЕ_ТРЕБОВАНИЯ_К_ПРОВЕДЕНИЮ_СОРЕВНОВАНИЙ.pdf
# `mode='paged'` is deprecated in favor of the 'by_page' chunking strategy. Learn more about chunking here: https://docs.unstructured.io/open-source/core-functionality/chunking
# Warning: No languages specified, defaulting to English.
# Loading PDFs:  30%|██▉       | 8/27 [05:39<11:10, 35.28s/it]
# Processing: pdf_rules\Любители\ПРЕДВАРИТЕЛЬНЫЕ_Технические_требования_2025_2026_послед.pdf
# `mode='paged'` is deprecated in favor of the 'by_page' chunking strategy. Learn more about chunking here: https://docs.unstructured.io/open-source/core-functionality/chunking
# Warning: No languages specified, defaulting to English.
# Loading PDFs:  33%|███▎      | 9/27 [05:49<08:12, 27.38s/it]
# Processing: pdf_rules\Любители\ПРЕДВАРИТЕЛЬНЫЕ_Технические_требования_взрослые_любители_2025_2026.pdf
# `mode='paged'` is deprecated in favor of the 'by_page' chunking strategy. Learn more about chunking here: https://docs.unstructured.io/open-source/core-functionality/chunking
# Warning: No languages specified, defaulting to English.
# Loading PDFs:  37%|███▋      | 10/27 [06:32<09:04, 32.03s/it]
# Processing: pdf_rules\Любители\ПРЕДВАРИТЕЛЬНЫЕ_Технические_требования_для_детей_любителей_2025_2026.pdf
# Warning: No languages specified, defaulting to English.
# `mode='paged'` is deprecated in favor of the 'by_page' chunking strategy. Learn more about chunking here: https://docs.unstructured.io/open-source/core-functionality/chunking
# Loading PDFs:  41%|████      | 11/27 [08:21<14:51, 55.71s/it]
# Processing: pdf_rules\Любители\ПРЕДВАРИТЕЛЬНЫЕ_Техтребования_Танцы_соло_2025_2026.pdf
# Warning: No languages specified, defaulting to English.
# `mode='paged'` is deprecated in favor of the 'by_page' chunking strategy. Learn more about chunking here: https://docs.unstructured.io/open-source/core-functionality/chunking
# Loading PDFs:  44%|████▍     | 12/27 [09:16<13:53, 55.59s/it]
# Processing: pdf_rules\Любители\Программа_тестирования_для_любителей.pdf
# `mode='paged'` is deprecated in favor of the 'by_page' chunking strategy. Learn more about chunking here: https://docs.unstructured.io/open-source/core-functionality/chunking
# Warning: No languages specified, defaulting to English.
# Loading PDFs:  48%|████▊     | 13/27 [09:28<09:52, 42.33s/it]
# Processing: pdf_rules\ISU\2700-ID-Novice-Communication-updated-June2-1759232286-9826.pdf
# Warning: No languages specified, defaulting to English.
# `mode='paged'` is deprecated in favor of the 'by_page' chunking strategy. Learn more about chunking here: https://docs.unstructured.io/open-source/core-functionality/chunking
ode='paged'` is deprecated in favor of the 'by_page' chunking strategy. Learn more about chunking here: https://docs.unstructured.io/open-source/core-functionality/chunking
# Loading PDFs:  96%|█████████▋| 26/27 [14:20<00:28, 28.70s/it]
# Processing: pdf_rules\ISU\WhoisresponsibleIDDeductionChartNovice20232024024531600_17327128446663.pdf
# `mode='paged'` is deprecated in favor of the 'by_page' chunking strategy. Learn more about chunking here: https://docs.unstructured.io/open-source/core-functionality/chunking
# Warning: No languages specified, defaulting to English.
# Loading PDFs: 100%|██████████| 27/27 [14:22<00:00, 31.95s/it]

# %%
error_pdf_files
# Out:
# []

# %% [markdown]
# # Splitter + Vector Database

# %%
def textSplitter(chunk_size, chunk_overlap):
    text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=chunk_size, 
            chunk_overlap=chunk_overlap,
            separators=["\n\n\n", "\n\n", "\n", " ", ""]
        )

    splits = text_splitter.split_documents(all_docs)
    print(f"Количество чанков: {len(splits)}")
    return splits

# %%
splits_3500 = textSplitter(chunk_size = 3500, chunk_overlap = 750)
# Сохраняем список чанков в файл
with open('chunks_3500.pkl', 'wb') as f:
    pickle.dump(splits_3500, f)


splits_2700 = textSplitter(chunk_size = 2700, chunk_overlap = 600)
# Сохраняем список чанков в файл
with open('chunks_2700.pkl', 'wb') as f:
    pickle.dump(splits_2700, f)


splits_2000 = textSplitter(chunk_size = 2000, chunk_overlap = 500)
# Сохраняем список чанков в файл
with open('chunks_2000.pkl', 'wb') as f:
    pickle.dump(splits_2000, f)
# Out:
# Количество чанков: 1358
# Количество чанков: 1741
# Количество чанков: 2332

# %%
# мультиязычная модель эмбеддингов, тк правила на русском и на английском

model_name = "BAAI/bge-m3"
model_kwargs = {'device': 'cuda'}
# model_kwargs = {'device': 'cpu'}
encode_kwargs = {'normalize_embeddings': True, 'batch_size': 32}

embeddings = HuggingFaceBgeEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs,
)
# Out:
# /tmp/ipython-input-3099715517.py:8: LangChainDeprecationWarning: The class `HuggingFaceBgeEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceBgeEmbeddings(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/54.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/687 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/444 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]

# %%
def save_loca_faiss(chunks_path,chunk_size):
    # # Загружаем чанки
    with open(chunks_path, 'rb') as f:
        splits = pickle.load(f)

    print(f"Загружено {len(splits)} чанков")

    batch_size = 100
    vectorstore = None
    for i in tqdm(range(0, len(splits), batch_size), desc="Векторизация"):
        batch = splits[i : i + batch_size]

        if vectorstore is None:
            # Создаем базу с первой пачкой
            vectorstore = FAISS.from_documents(
                batch,
                embeddings,
                distance_strategy=DistanceStrategy.COSINE
            )
        else:
            # Добавляем остальные пачки
            vectorstore.add_documents(batch)

    folder_name = f"faiss_index_bge_m3_{chunk_size}"
    vectorstore.save_local(folder_name)

# %%
save_loca_faiss('chunks_3500.pkl', chunk_size = 3500)
save_loca_faiss('chunks_2700.pkl', chunk_size = 2700)
save_loca_faiss('chunks_2000.pkl', chunk_size = 2000)
# Out:
# Загружено 1358 чанков
# Векторизация: 100%|██████████| 14/14 [03:15<00:00, 13.98s/it]
# Загружено 1741 чанков
# Векторизация: 100%|██████████| 18/18 [03:16<00:00, 10.92s/it]
# Загружено 2332 чанков
# Векторизация: 100%|██████████| 24/24 [03:16<00:00,  8.20s/it]

# %% [markdown]
# # RAG

# %%
# загружаем базу векторную данных
vectorstore_db = FAISS.load_local(
    "faiss_index_bge_m3_2700",
    embeddings,
    allow_dangerous_deserialization=True
)

# %%
retriever = vectorstore_db.as_retriever(
    search_type="similarity",  # семантическая близость, косинусное расстояние
    # search_type = 'mmr',  # избегаение дублировнаия информации в ответе
    search_kwargs={"k": 6}  # 6 ближайших соседей
)

# %%
print(retriever.invoke('С какого ребра выполняется прыжок флип/Flip?')[0].page_content)
# Out:
# --- Table 46 ---
# | Отрыв с                                                                                       |
# | неправильного                                                                                 |
# | ребра                                                                                         |
# | (Флип/Лутц)                                                                                   |
# |:----------------------------------------------------------------------------------------------|
# | Отрыв Флипа с заднего внутреннего ребра, отрыв Лутца с заднего наружного ребра.  В случаях    |
# | отсутствия отрыва с чистого правильного ребра Техническая Бригада указывает судьям на         |
# | наличие этой ошибки, используя знаки “e” (ребро) и “!” (внимание). Техническая бригада может  |
# | смотреть повтор в замедленной скорости.                                                       |
# | Техническая Бригада использует знак “e” (ребро), если ребро отрыва явно неправильно. Базовые  |
# | стоимости прыжков со знаком “e” приведены в специальных строчках Шкалы Стоимости.             |
# | Техническая Бригада использует знак “!”, если ребро отрыва не ясно. В этих случаях Базовая    |
# | стоимость не уменьшается. Обе эти ошибки отражаются судьями в своих GOE.                      |
# ------------------

# %%
print(retriever.invoke(
    'что такое любительское фигурное катание'
)[0].page_content)
# Out:
# 1. ОБЩИЕ ПОЛОЖЕНИЯ
# Настоящие специальные требования (далее – Требования) являются локальным нормативным актом Общероссийской общественной организации «Федерация фигурного катания на коньках России» (далее – ФФККР) и разработаны в соответствии с Федеральным законом от 04.12.2007 г. № 329-ФЗ «О физической культуре и спорте в Российской Федерации», законами, регулирующими деятельность спортивных, общественных и некоммерческих объединений и организаций, иными нормативно-правовыми актами Российской Федерации, Правилами вида спорта "Фигурное катание на коньках" (далее - Правила), Уставом и внутренними документами ФФККР.
# Действие настоящих Требований распространяется на все официальные спортивные мероприятия для взрослых любителей, проводимых на территории Российской Федерации, которые в соответствии с п.2.2. Правил являются неклассификационными программами.
# 1.1. Далее в тексте настоящих Требований используются следующие термины,
# определения и сокращения:
# – ВИД ПРОГРАММЫ – спортивное соревнование по фигурному катанию на коньках или одной из его дисциплин, в результате которого осуществляется распределение мест и (или) медалей среди участников спортивного соревнования; – ЛЮБИТЕЛЬСКИЙ СПОРТ – часть массового спорта, направленная на организацию и проведение спортивных соревнований, которые не связаны с подготовкой спортивных сборных команд Российской Федерации и спортивных сборных команд субъектов Российской Федерации и участие в которых не направлено на систематическое получение дохода и не является трудовой функцией спортсменов, принимающих участие в таких соревнованиях (далее - любительские спортивные соревнования);
